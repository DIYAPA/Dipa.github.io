# %% [markdown]
# <a href="https://colab.research.google.com/github/DIYAPA/Dipa.github.io/blob/main/coordinate_geometry.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **EDA1**

# %%
# EDA

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/data.csv")

# %%
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
df.head(2)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650

# %%
df.shape
# Out:
# (11914, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
#drop any column

# %%
df.head(2)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650

# %%
df1=df.copy()

# %%
df2=df1.drop(['Make','Model'],axis=1)#axis=1--->column
df2.shape
# Out:
# (11914, 14)

# %%
df1.shape #main data is not effected
# Out:
# (11914, 16)

# %%
df2.head(2)
# Out:
#    Year             Engine Fuel Type  Engine HP  Engine Cylinders  \
# 0  2011  premium unleaded (required)      335.0               6.0
# 1  2011  premium unleaded (required)      300.0               6.0
#
#   Transmission Type     Driven_Wheels  Number of Doors  \
# 0            MANUAL  rear wheel drive              2.0
# 1            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650

# %%
df1.drop(['Make','Model'],axis=1,inplace=True)# if we give inplace ,main will be efefcted

# %%
df1.shape
# Out:
# (11914, 14)

# %%
#rename few columns

# %%
df=df.rename(columns={'Engine Fuel Type':'Engine_fuel','Engine Cylinders': 'cylinder' })

# %%
df.head(2)
# Out:
#   Make       Model  Year                  Engine_fuel  Engine HP  cylinder  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0       6.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0       6.0
#
#   Transmission Type     Driven_Wheels  Number of Doors  \
# 0            MANUAL  rear wheel drive              2.0
# 1            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650

# %%
#value _counts

# %%
df.Make.value_counts()
# Out:
# Make
# Chevrolet        1123
# Ford              881
# Volkswagen        809
# Toyota            746
# Dodge             626
# Nissan            558
# GMC               515
# Honda             449
# Mazda             423
# Cadillac          397
# Mercedes-Benz     353
# Suzuki            351
# BMW               334
# Infiniti          330
# Audi              328
# Hyundai           303
# Volvo             281
# Subaru            256
# Acura             252
# Kia               231
# Mitsubishi        213
# Lexus             202
# Buick             196
# Chrysler          187
# Pontiac           186
# Lincoln           164
# Oldsmobile        150
# Land Rover        143
# Porsche           136
# Saab              111
# Aston Martin       93
# Plymouth           82
# Bentley            74
# Ferrari            69
# FIAT               62
# Scion              60
# Maserati           58
# Lamborghini        52
# Rolls-Royce        31
# Lotus              29
# Tesla              18
# ...

# %%
df['Make'].value_counts() #same
# Out:
# Make
# Chevrolet        1123
# Ford              881
# Volkswagen        809
# Toyota            746
# Dodge             626
# Nissan            558
# GMC               515
# Honda             449
# Mazda             423
# Cadillac          397
# Mercedes-Benz     353
# Suzuki            351
# BMW               334
# Infiniti          330
# Audi              328
# Hyundai           303
# Volvo             281
# Subaru            256
# Acura             252
# Kia               231
# Mitsubishi        213
# Lexus             202
# Buick             196
# Chrysler          187
# Pontiac           186
# Lincoln           164
# Oldsmobile        150
# Land Rover        143
# Porsche           136
# Saab              111
# Aston Martin       93
# Plymouth           82
# Bentley            74
# Ferrari            69
# FIAT               62
# Scion              60
# Maserati           58
# Lamborghini        52
# Rolls-Royce        31
# Lotus              29
# Tesla              18
# ...

# %%
#drop duplicates

# %%
df1=df.drop_duplicates()
print(df1.shape, df.shape)
# Out:
# (11199, 16) (11914, 16)

# %%
#groupby operation

# %%
df.groupby(['Make'])['Number of Doors'].mean()
# Out:
# Make
# Acura            3.619048
# Alfa Romeo       2.000000
# Aston Martin     2.150538
# Audi             3.469512
# BMW              3.161677
# Bentley          2.675676
# Bugatti          2.000000
# Buick            3.836735
# Cadillac         3.602015
# Chevrolet        3.381122
# Chrysler         3.625668
# Dodge            3.210863
# FIAT             2.903226
# Ferrari          2.000000
# Ford             3.383655
# GMC              3.495146
# Genesis          4.000000
# HUMMER           4.000000
# Honda            3.536748
# Hyundai          3.498350
# Infiniti         3.545455
# Kia              3.939394
# Lamborghini      2.000000
# Land Rover       3.790210
# Lexus            3.712871
# Lincoln          3.853659
# Lotus            2.000000
# Maserati         2.793103
# Maybach          4.000000
# Mazda            3.460993
# McLaren          2.000000
# Mercedes-Benz    3.351275
# Mitsubishi       3.596244
# Nissan           3.433692
# Oldsmobile       3.573333
# ...

# %%
df.groupby(['MSRP'])['Number of Doors'].median()
# Out:
# MSRP
# 2000       3.0
# 2002       4.0
# 2003       4.0
# 2008       2.5
# 2012       2.0
#           ...
# 1380000    4.0
# 1382750    4.0
# 1500000    2.0
# 1705769    2.0
# 2065902    2.0
# Name: Number of Doors, Length: 6049, dtype: float64

# %%
#to perform mean and medin in single step

# %%
df.groupby(['Transmission Type']).agg({'MSRP':['mean','median']})
# Out:
#                            MSRP
#                            mean   median
# Transmission Type
# AUTOMATED_MANUAL   99508.370607  38337.5
# AUTOMATIC          41110.331720  32565.0
# DIRECT_DRIVE       47351.250000  35825.0
# MANUAL             26663.644293  18720.0
# UNKNOWN             3040.736842   2000.0

# %%
df.head(2)
# Out:
#   Make       Model  Year                  Engine_fuel  Engine HP  cylinder  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0       6.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0       6.0
#
#   Transmission Type     Driven_Wheels  Number of Doors  \
# 0            MANUAL  rear wheel drive              2.0
# 1            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650

# %%
df.groupby(['Transmission Type']).agg({'MSRP':['mean','median']}).reset_index()
# Out:
#   Transmission Type          MSRP
#                              mean   median
# 0  AUTOMATED_MANUAL  99508.370607  38337.5
# 1         AUTOMATIC  41110.331720  32565.0
# 2      DIRECT_DRIVE  47351.250000  35825.0
# 3            MANUAL  26663.644293  18720.0
# 4           UNKNOWN   3040.736842   2000.0

# %%
#outliers/large data

# %%
#Mean: Useful for datasets without extreme outliers and when all values are equally important.
#Median: Better for datasets with outliers or skewed distributions, as it provides a better measure of central tendency in those cases.

# %%
#nulls in data

# %%
df.dropna()
# Out:
#           Make       Model  Year                     Engine_fuel  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df.shape
# Out:
# (11914, 16)

# %%
df.isnull()#check each values and make true is null is shown
# Out:
#         Make  Model   Year  Engine_fuel  Engine HP  cylinder  \
# 0      False  False  False        False      False     False
# 1      False  False  False        False      False     False
# 2      False  False  False        False      False     False
# 3      False  False  False        False      False     False
# 4      False  False  False        False      False     False
# ...      ...    ...    ...          ...        ...       ...
# 11909  False  False  False        False      False     False
# 11910  False  False  False        False      False     False
# 11911  False  False  False        False      False     False
# 11912  False  False  False        False      False     False
# 11913  False  False  False        False      False     False
#
#        Transmission Type  Driven_Wheels  Number of Doors  Market Category  \
# 0                  False          False            False            False
# 1                  False          False            False            False
# ...

# %%
df.isnull().sum() #count of null
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine_fuel             3
# Engine HP              69
# cylinder               30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
# df.info also give non-null

# %%
df.isnull().mean()*100
# Out:
# Make                  0.000000
# Model                 0.000000
# Year                  0.000000
# Engine_fuel           0.025180
# Engine HP             0.579151
# cylinder              0.251805
# Transmission Type     0.000000
# Driven_Wheels         0.000000
# Number of Doors       0.050361
# Market Category      31.408427
# Vehicle Size          0.000000
# Vehicle Style         0.000000
# highway MPG           0.000000
# city mpg              0.000000
# Popularity            0.000000
# MSRP                  0.000000
# dtype: float64

# %%
#drop null

# %%
#imputation techniques

# %%
#replace nulls with mean/median
#build model to predict the nulls value

# %%
#outlier is an extreme values

# %%
#product sales column[1,100]:other entries where value =1000,5000

# %%
#numerical column will hv outliers

# %%
sns.histplot(df['MSRP'])
# Out:
# <Axes: xlabel='MSRP', ylabel='Count'>

# %%
sns.boxplot(df['MSRP'])
# Out:
# <Axes: ylabel='MSRP'>

# %%
df.head(2)
# Out:
#   Make       Model  Year                  Engine_fuel  Engine HP  cylinder  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0       6.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0       6.0
#
#   Transmission Type     Driven_Wheels  Number of Doors  \
# 0            MANUAL  rear wheel drive              2.0
# 1            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650

# %%
sns.boxplot(df['Engine HP'])
# Out:
# <Axes: ylabel='Engine HP'>

# %%
#iqr=q3-q1
#interquartilerange

# %%
#central line is median q2

# %%
#Upper Bound for Outliers q3+1.5iqr
##lower Bound for Outliers q1-1.5iqr

# %%
#iqr

# %% [markdown]
# ### **IQR**

# %%
q1=df['Engine HP'].quantile (0.25)
q3=df['Engine HP'].quantile(0.75)

# %%
iqr=q3-q1
iqr
# Out:
# 130.0

# %%
#how to remove outlinear from all numerical cloumn using fn
#if any value is above (q3+1.5*iqr) below q1-1.5*iqr

# %%
#df['Engine HP']= df['Engine HP'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# <ipython-input-43-8b1d8650e578> in <cell line: 1>()
# ----> 1 df['Engine HP']= df['Engine HP'].astype(int)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6322         else:
#    6323             # else, only a single dtype is given
# -> 6324             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325             return self._constructor(new_data).__finalize__(self, method="astype")
#    6326
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     449             copy = False
#     450
# --> 451         return self.apply(
#     452             "astype",
#     453             dtype=dtype,
#
# ...

# %%
lower_b=q1 - 1.5 * iqr
upper_b=q3 + 1.5 * iqr

# %%
df['Engine HP'] = df['Engine HP'][~((df['Engine HP'] < (q1 - 1.5 * iqr)) | (df['Engine HP'] > (q3 + 1.5 * iqr)))]

# %%
df['Engine HP']
# Out:
# 0        335.0
# 1        300.0
# 2        300.0
# 3        230.0
# 4        230.0
#          ...
# 11909    300.0
# 11910    300.0
# 11911    300.0
# 11912    300.0
# 11913    221.0
# Name: Engine HP, Length: 11914, dtype: float64

# %%
#SCATTER PLOT BETWEEN 2 VARIBLES

# %%
plt.scatter(df['Engine HP'], df['MSRP'])

# %%
plt.hist(df['MSRP'])
plt.xlabel('range')
plt.ylabel('MSRP')
plt.show()

# %% [markdown]
# ### ##**EDA2**

# %%
#imputation techniques

# %%
#replace all nulls with mean and median
#build model to predict all the null value

# %%
df.isnull().mean()*100
# Out:
# Make                  0.000000
# Model                 0.000000
# Year                  0.000000
# Engine Fuel Type      0.025180
# Engine HP             0.579151
# Engine Cylinders      0.251805
# Transmission Type     0.000000
# Driven_Wheels         0.000000
# Number of Doors       0.050361
# Market Category      31.408427
# Vehicle Size          0.000000
# Vehicle Style         0.000000
# highway MPG           0.000000
# city mpg              0.000000
# Popularity            0.000000
# MSRP                  0.000000
# dtype: float64

# %%
df['Engine HP']=df['Engine HP'].fillna(df['Engine HP'].median())
df['Engine HP'].isnull().mean()*100
# Out:
# 0.0

# %%
df.head(2)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650

# %%
#replace above with mode value

# %%
df['Engine HP']=df['Engine HP'].fillna(df['Engine HP'].mode())
df['Engine HP'].isnull().mode()*100
# Out:
# 0    0
# Name: Engine HP, dtype: int64

# %% [markdown]
# ### **predict null using ML model**

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# %%
data={
    'feature1': [1,2,np.nan,4,5],
    'feature2': [6,np.nan,8,9,10],
    'feature3': [1,2,3,4,5]}

# %%
df=pd.DataFrame(data)
df.head()
# Out:
#    feature1  feature2  feature3
# 0       1.0       6.0         1
# 1       2.0       NaN         2
# 2       NaN       8.0         3
# 3       4.0       9.0         4
# 4       5.0      10.0         5

# %%
df.isnull().mean()*100
# Out:
# feature1    20.0
# feature2    20.0
# feature3     0.0
# dtype: float64

# %%
x=df[['feature1','feature2']]
y=df[['feature3']]

# %%
x.head()
# Out:
#    feature1  feature2
# 0       1.0       6.0
# 1       2.0       NaN
# 2       NaN       8.0
# 3       4.0       9.0
# 4       5.0      10.0

# %%
#separte the f1,f2 and f3 bcz we dont want to effect each other

# %%
for column in df.columns:
  if df[column].isnull().any():
    #separte data in to trainning and testing purpose
     known_data=df[df[column].notnull()]
     unknown_data=df[df[column].isnull()]

     x_train =known_data.drop(column, axis =1)
     y_train=known_data[column]

     x_test =unknown_data.drop(column, axis =1)
     #combine x and train data to remove any nulls

     train_data= pd.concat([x_train, y_train], axis=1).dropna()
     x_train =train_data.drop(column, axis =1)
     y_train=train_data[column]

    #train model
     LR=LinearRegression() #randomforestregression
     LR.fit(x_train,y_train)

     #predict model
     predicted_value =LR.predict(x_test)

     #impute missing value

     df.loc[df[column].isnull(), column] =predicted_value
df.head()
# Out:
#    feature1  feature2  feature3
# 0       1.0       6.0         1
# 1       2.0       7.0         2
# 2       3.0       8.0         3
# 3       4.0       9.0         4
# 4       5.0      10.0         5
